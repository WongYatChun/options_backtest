# %%
import os
from datetime import datetime
import pandas as pd
import numpy as np
from optionStrategies import long_call, short_call, long_call_long_put, long_call_short_put
from data_import import get_data
from tradeStat import results
from pathlib import PurePath, Path

pp = PurePath(Path.cwd()).parts[:]
pdir = PurePath(*pp)
infp=PurePath(pdir)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
infp
# Out:
# <style>.container { width:100% !important; }</style>
# PureWindowsPath('C:/Users/rex.wong/Documents/Project2_options_1213/Project2_options')

# %%
STRAT = "after_short_straddle"
MARKET = "ASX"


path = os.path.join(infp ,STRAT, MARKET)

# %%
ASX_STRAT_after = pd.DataFrame()

entries = os.listdir(path)
for entry in entries:
    xls_file = os.path.join(path, entry)
    event_name = entry.replace(".xls","")
    df = pd.read_excel(xls_file).assign(event_name = lambda x: event_name, dtm = lambda x: x['maturity_date'] - x['entry_date'])
    ASX_STRAT_after = ASX_STRAT_after.append(df, ignore_index = True)

# %%
df0 = ASX_STRAT_after.drop(["trade_num", "entry_gamma"], axis = 1)

# %%
df0['Average_Daily_Return_pct'][df0['Average_Daily_Return_pct'] > 0 ].count() / df0['Average_Daily_Return_pct'].count()
# Out:
# 0.76388888888888884

# %%
df0[df0['Average_Daily_Return_pct'] <= 0 ]
# Out:
#    entry_date  exit_date maturity_date  entry_delta  entry_vega  entry_rho  entry_theta  entry_price  exit_price  holding_period  num_contracts  total_t_cost  Actual_Profit  Average_Day_Profit  Total_Return_pct  Average_Daily_Return_pct                                         event_name     dtm
# 2  2014-09-09 2014-09-11    2014-09-18         0.04        7.00       0.04        -3.92         7100       -7670               2             14           280          -8260            -4130.00         -0.275333                     -0.14       (ASX) 10 SEP 2014 KEY ECB ANNOUNCEMENT_trade  9 days
# 11 2017-12-11 2017-12-14    2018-01-18         0.04       15.35       0.11        -1.81        13980      -13920               3              7           140            280               93.33          0.009333                      0.00              (ASX) 13 DEC 2017 FED RATE HIKE_trade 38 days
# 13 2017-12-12 2017-12-14    2018-01-18         0.00       15.20      -0.18        -1.79        13280      -13340               2              8           160           -640             -320.00         -0.021333                     -0.01              (ASX) 13 DEC 2017 FED RATE HIKE_trade 37 days
# 23 2013-11-13 2013-11-14    2013-12-19         0.03       13.26       0.00        -2.39        17400      -17560               1              6           120          -1080            -1080.00         -0.036000                     -0.04       (ASX) 13 NOV 2013 KEY ECB ANNOUNCEMENT_trade 36 days
# 33 2017-06-14 2017-06-15    2017-07-20        -0.02       14.55      -0.24        -2.20        15870      -16370               1              6           120          -3120            -3120.00         -0.104000                     -0.10              (ASX) 14 JUN 2017 FED RATE HIKE_trade 36 days
# 34 2017-06-14 2017-06-15    2017-08-17        -0.01       19.31      -0.45        -1.71        23330      -23500               1              4            80           -760             -760.00         -0.025333                     -0.03              (ASX) 14 JUN 2017 FED RATE HIKE_trade 64 days
# 41 2015-12-14 2015-12-17    2016-01-21         0.00       12.62      -0.26        -3.20        24400      -27210               3              4            80         -11320            -3773.33         -0.377333                     -0.13              (ASX) 16 DEC 2015 FED RATE HIKE_trade 38 days
# 42 2015-12-14 2015-12-17    2016-02-18        -0.01       16.58      -0.66        -2.38        31710      -34010               3              3            60          -6960            -2320.00         -0.232000                     -0.08              (ASX) 16 DEC 2015 FED RATE HIKE_trade 66 days
# 43 2015-12-15 2015-12-17    2016-01-21         0.02       12.42      -0.18        -3.30        24540      -28770               2              4            80         -17000            -8500.00         -0.566667                     -0.28              (ASX) 16 DEC 2015 FED RATE HIKE_trade 37 days
# 44 2015-12-15 2015-12-17    2016-02-18         0.01       16.40      -0.54        -2.46        32330      -35290               2              3            60          -8940            -4470.00         -0.298000                     -0.15              (ASX) 16 DEC 2015 FED RATE HIKE_trade 65 days
# 53 2017-06-05 2017-06-09    2017-06-15         0.02        7.60      -0.01        -4.26         8530       -9360               4             12           240         -10200            -2550.00         -0.340000                     -0.08  (ASX) 8 JUN 2017 EURZONE RATE ANNOUNCEMENT & U... 10 days
# 54 2017-06-05 2017-06-09    2017-07-20        -0.04       16.01      -0.50        -1.92        17310      -18150               4              6           120          -5160            -1290.00         -0.172000                     -0.04  (ASX) 8 JUN 2017 EURZONE RATE ANNOUNCEMENT & U... 45 days
# 63 2013-05-07 2013-05-09    2013-06-20         0.02       14.16      -0.08        -2.06        18290      -18590               2              5           100          -1600             -800.00         -0.053333                     -0.03        (ASX) 8 MAY 2013 KEY ECB ANNOUNCEMENT_trade 44 days
# 66 2015-12-07 2015-12-10    2015-12-17         0.02        6.80      -0.01        -6.25        12520      -14230               3              8           160         -13840            -4613.33         -0.461333                     -0.15        (ASX) 9 DEC 2015 KEY ECB ANNOUNCEMENT_trade 10 days
# 67 2015-12-07 2015-12-10    2016-01-21        -0.01       14.36      -0.34        -2.70        24470      -25550               3              4            80          -4400            -1466.67         -0.146667                     -0.05        (ASX) 9 DEC 2015 KEY ECB ANNOUNCEMENT_trade 45 days
# 69 2015-12-08 2015-12-10    2016-01-21         0.00       14.08      -0.28        -2.82        24950      -24860               2              4            80            280              140.00          0.009333                      0.00        (ASX) 9 DEC 2015 KEY ECB ANNOUNCEMENT_trade 44 days
# 71 2015-12-09 2015-12-10    2016-01-21         0.00       13.84      -0.31        -2.83        24480      -24780               1              4            80          -1280            -1280.00         -0.042667                     -0.04        (ASX) 9 DEC 2015 KEY ECB ANNOUNCEMENT_trade 43 days

# %%
df0[df0['Average_Daily_Return_pct'] > 0 ]
# Out:
#    entry_date  exit_date maturity_date  entry_delta  entry_vega  entry_rho  entry_theta  entry_price  exit_price  holding_period  num_contracts  total_t_cost  Actual_Profit  Average_Day_Profit  Total_Return_pct  Average_Daily_Return_pct                                         event_name     dtm
# 0  2014-09-08 2014-09-11    2014-09-18        -0.01        7.36      -0.03        -4.09         8200       -6700               3             12           240          17760             5920.00          0.592000                      0.20       (ASX) 10 SEP 2014 KEY ECB ANNOUNCEMENT_trade 10 days
# 1  2014-09-08 2014-09-11    2014-10-16        -0.05       14.27      -0.42        -2.05        15540      -14320               3              6           120           7200             2400.00          0.240000                      0.08       (ASX) 10 SEP 2014 KEY ECB ANNOUNCEMENT_trade 38 days
mean_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].mean()
std_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].std()
count_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].count()

print(mean_above40)
print(std_above40)
print(count_above40)
print("Sharpe ratio for dtm >= 40 days: ", mean_above40 / std_above40 / np.sqrt(count_above40))
# Out:
# 0.03925925925925925
# 0.07146413441106321
# 27
# Sharpe ratio for dtm >= 40 days:  0.105723633672

# %%
mean_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].mean()
std_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].std()
count_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].count()

print(mean_below40)
print(std_below40)
print(count_below40)
print("Sharpe ratio for dtm < 40 days: ", mean_below40 / std_below40 / np.sqrt(count_below40))
# Out:
# 0.08088888888888889
# 0.1364788065835302
# 45
# Sharpe ratio for dtm < 40 days:  0.0883522058395

# %% [markdown]
# ### NKY Market

# %%
MARKET = "NKY"


path = os.path.join(infp ,STRAT, MARKET)

NKY_STRAT_after = pd.DataFrame()

entries = os.listdir(path)
for entry in entries:
    xls_file = os.path.join(path, entry)
    df = pd.read_excel(xls_file)
    event_name = entry.replace(".xls","")
    df = pd.read_excel(xls_file).assign(event_name = lambda x: event_name, dtm = lambda x: x['maturity_date'] - x['entry_date'])
    NKY_STRAT_after = NKY_STRAT_after.append(df, ignore_index = True)
df0 = NKY_STRAT_after.drop(["trade_num", "entry_gamma"], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-afe3cfa07016> in <module>()
#       8
#       9 entries = os.listdir(path)
# ---> 10 for entry in entries[:NUM_FILE]:
#      11     xls_file = os.path.join(path, entry)
#      12     df = pd.read_excel(xls_file)
#
# NameError: name 'NUM_FILE' is not defined

# %%
df0['Average_Daily_Return_pct'][df0['Average_Daily_Return_pct'] > 0 ].count() / df0['Average_Daily_Return_pct'].count()

# %%
df0[df0['Average_Daily_Return_pct'] <= 0 ]

# %%
df0[df0['Average_Daily_Return_pct'] > 0 ]

# %%
mean_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].mean()
std_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].std()
count_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].count()

print(mean_above40)
print(std_above40)
print(count_above40)
print("Sharpe ratio for dtm >= 40 days: ", mean_above40 / std_above40 / np.sqrt(count_above40))

# %%
mean_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].mean()
std_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].std()
count_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].count()

print(mean_below40)
print(std_below40)
print(count_below40)
print("Sharpe ratio for dtm < 40 days: ", mean_below40 / std_below40 / np.sqrt(count_below40))
