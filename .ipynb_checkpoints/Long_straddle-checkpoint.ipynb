# %%
import os
from datetime import datetime
import pandas as pd
import numpy as np

from optionStrategies import long_call, short_call, long_call_long_put, long_call_short_put
from data_import import get_data
from tradeStat import results
from pathlib import PurePath, Path

pp = PurePath(Path.cwd()).parts[:]
pdir = PurePath(*pp)
infp=PurePath(pdir)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
infp
# Out:
# <style>.container { width:100% !important; }</style>
# PurePosixPath('/home/Rex/Documents/Project2_options_1211/Project2_options')

# %%
STRAT = "long_straddle"
MARKET = "ASX"


path = os.path.join(infp ,STRAT, MARKET)

# %%
ASX_STRAT_after = pd.DataFrame()

entries = os.listdir(path)
for entry in entries[:NUM_FILE]:
    event_name = entry.replace(".xls","")
    xls_file = os.path.join(path, entry)
    df = pd.read_excel(xls_file).assign(event_name = lambda x: event_name, dtm = lambda x: x['maturity_date'] - x['entry_date'])
    ASX_STRAT_after = ASX_STRAT_after.append(df, ignore_index = True)

# %%
df0 = ASX_STRAT_after.drop(["trade_num", "entry_gamma"], axis = 1)

# %%
df0['Average_Daily_Return_pct'][df0['Average_Daily_Return_pct'] > 0 ].count() / df0['Average_Daily_Return_pct'].count()
# Out:
# 0.75

# %%
df0[df0['Average_Daily_Return_pct'] <= 0 ]
# Out:
#   entry_date  exit_date maturity_date  entry_delta  entry_vega  entry_rho  entry_theta  entry_price  exit_price  holding_period  num_contracts  total_t_cost  Actual_Profit  Average_Day_Profit  Total_Return_pct  Average_Daily_Return_pct                                   event_name     dtm
# 0 2014-11-03 2014-11-05    2014-11-20         0.01        9.46      -0.03        -3.18       -10860        9670               2              9           180         -10890             -5445.0            -10.89                     -5.44  (ASX) 4 NOV 2014 USA MIDTERM ELECTION_trade 17 days
# 1 2014-11-03 2014-11-05    2014-12-18        -0.03       15.34      -0.39        -1.97       -17690       16910               2              6           120          -4800             -2400.0             -4.80                     -2.40  (ASX) 4 NOV 2014 USA MIDTERM ELECTION_trade 45 days
# 2 2014-11-04 2014-11-05    2014-11-20        -0.07        9.17      -0.21        -3.15       -10080        9770               1             10           200          -3300             -3300.0             -3.30                     -3.30  (ASX) 4 NOV 2014 USA MIDTERM ELECTION_trade 16 days
# 3 2014-11-04 2014-11-05    2014-12-18         0.02       15.20      -0.06        -1.93       -17080       16910               1              6           120          -1140             -1140.0             -1.14                     -1.14  (ASX) 4 NOV 2014 USA MIDTERM ELECTION_trade 44 days

# %%
df0[df0['Average_Daily_Return_pct'] > 0 ]
# Out:
#    entry_date  exit_date maturity_date  entry_delta  entry_vega  entry_rho  entry_theta  entry_price  exit_price  holding_period  num_contracts  total_t_cost  Actual_Profit  Average_Day_Profit  Total_Return_pct  Average_Daily_Return_pct                                   event_name     dtm
# 4  2016-11-07 2016-11-09    2016-11-17         0.00        6.92      -0.04        -6.39       -12790       16850               2              8           160          32320            16160.00             32.32                     16.16  (ASX) 8 NOV 2016 USA GENERAL ELECTION_trade 10 days
# 5  2016-11-07 2016-11-09    2016-12-15        -0.02       13.44      -0.34        -2.73       -20790       23060               2              5           100          11250             5625.00             11.25                      5.62  (ASX) 8 NOV 2016 USA GENERAL ELECTION_trade 38 days
# 6  2016-11-08 2016-11-09    2016-11-17         0.04        6.58       0.01        -7.31       -13210       16850               1              8           160          28960            28960.00             28.96                     28.96  (ASX) 8 NOV 2016 USA GENERAL ELECTION_trade  9 days
# 7  2016-11-08 2016-11-09    2016-12-15         0.00       13.30      -0.21        -2.73       -20280       23060               1              5           100          13800            13800.00             13.80                     13.80  (ASX) 8 NOV 2016 USA GENERAL ELECTION_trade 37 days
# 8  2016-06-20 2016-06-24    2016-07-21         0.00       12.18      -0.17        -3.57       -22260       25480               4              4            80          12800             3200.00             12.80                      3.20      (ASX) 23 JUN 2016 BREXIT ELECTION_trade 31 days
# 9  2016-06-20 2016-06-24    2016-08-18        -0.01       16.74      -0.54        -2.49       -29660       32360               4              3            60           8040             2010.00              8.04                      2.01      (ASX) 23 JUN 2016 BREXIT ELECTION_trade 59 days
# 10 2016-06-21 2016-06-24    2016-07-21        -0.02       12.02      -0.25        -3.57       -21470       25850               3              5           100          21800             7266.67             21.80                      7.27      (ASX) 23 JUN 2016 BREXIT ELECTION_trade 30 days
# 11 2016-06-21 2016-06-24    2016-08-18         0.00       16.64      -0.45        -2.50       -30420       33830               3              3            60          10170             3390.00             10.17                      3.39      (ASX) 23 JUN 2016 BREXIT ELECTION_trade 58 days
# 12 2016-06-22 2016-06-24    2016-07-21        -0.02       11.80      -0.27        -3.86       -22460       25850               2              4            80          13480             6740.00             13.48                      6.74      (ASX) 23 JUN 2016 BREXIT ELECTION_trade 29 days
# 13 2016-06-22 2016-06-24    2016-08-18         0.00       16.50      -0.50        -2.58       -30870       33830               2              3            60           8820             4410.00              8.82                      4.41      (ASX) 23 JUN 2016 BREXIT ELECTION_trade 57 days
# 14 2016-06-23 2016-06-24    2016-07-21         0.00       11.62      -0.14        -4.05       -22790       25850               1              4            80          12160            12160.00             12.16                     12.16      (ASX) 23 JUN 2016 BREXIT ELECTION_trade 28 days
# 15 2016-06-23 2016-06-24    2016-08-18        -0.01       16.38      -0.51        -2.63       -29660       32730               1              3            60           9150             9150.00              9.15                      9.15      (ASX) 23 JUN 2016 BREXIT ELECTION_trade 56 days

# %%
mean_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].mean()
std_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].std()
count_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].count()

print(mean_above40)
print(std_above40)
print(count_above40)
print("Sharpe ratio for dtm >= 40 days: ", mean_above40 / std_above40 / np.sqrt(count_above40))
# Out:
# 2.57
# 4.150493946508054
# 6
# Sharpe ratio for dtm >= 40 days:  0.25278873310364725

# %%
mean_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].mean()
std_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].std()
count_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].count()

print(mean_below40)
print(std_below40)
print(count_below40)
print("Sharpe ratio for dtm < 40 days: ", mean_below40 / std_below40 / np.sqrt(count_below40))
# Out:
# 8.517
# 9.962866666889717
# 10
# Sharpe ratio for dtm < 40 days:  0.2703350323974803

# %% [markdown]
# ## NKY Market

# %%
MARKET = "NKY"


path = os.path.join(infp ,STRAT, MARKET)

NKY_STRAT_after = pd.DataFrame()

entries = os.listdir(path)
for entry in entries[:NUM_FILE]:
    event_name = entry.replace(".xls","")
    xls_file = os.path.join(path, entry)
    df = pd.read_excel(xls_file).assign(event_name = lambda x: event_name, dtm = lambda x: x['maturity_date'] - x['entry_date'])
    NKY_STRAT_after = NKY_STRAT_after.append(df, ignore_index = True)
df0 = NKY_STRAT_after.drop(["trade_num", "entry_gamma"], axis = 1)

# %%
df0['Average_Daily_Return_pct'][df0['Average_Daily_Return_pct'] > 0 ].count() / df0['Average_Daily_Return_pct'].count()
# Out:
# 0.5434782608695652

# %%
df0[df0['Average_Daily_Return_pct'] <= 0 ]
# Out:
#    entry_date  exit_date maturity_date  entry_delta  entry_vega  entry_rho  entry_theta  entry_price  exit_price  holding_period  num_contracts  total_t_cost  Actual_Profit  Average_Day_Profit  Total_Return_pct  Average_Daily_Return_pct                                         event_name     dtm
# 18 2014-11-04 2014-11-05    2014-11-14         0.01       22.26      -0.19       -37.72       -75500       59500               1             40             0        -640000          -640000.00        -21.333333                    -21.33        (NKY) 4 NOV 2014 USA MIDTERM ELECTION_trade 10 days
# 19 2014-11-04 2014-11-05    2014-12-12         0.01       43.33      -1.03       -15.62      -119000      111500               1             25             0        -187500          -187500.00         -6.250000                     -6.25        (NKY) 4 NOV 2014 USA MIDTERM ELECTION_trade 38 days
# 26 2014-06-09 2014-06-12    2014-07-11         0.00       35.68      -0.60       -10.07       -64500       59500               3             47             0        -235000           -78333.33         -7.833333                     -2.61       (NKY) 11 JUN 2014 KEY ECB ANNOUNCEMENT_trade 32 days
# 27 2014-06-09 2014-06-12    2014-08-08         0.00       48.78      -1.52        -7.82       -94000       85500               3             32             0        -272000           -90666.67         -9.066667                     -3.02       (NKY) 11 JUN 2014 KEY ECB ANNOUNCEMENT_trade 60 days
# 28 2014-06-10 2014-06-12    2014-07-11         0.00       34.82      -0.62       -10.24       -63500       59500               2             47             0        -188000           -94000.00         -6.266667                     -3.13       (NKY) 11 JUN 2014 KEY ECB ANNOUNCEMENT_trade 31 days
# 29 2014-06-10 2014-06-12    2014-08-08         0.00       47.96      -1.55        -7.65       -90500       86000               2             33             0        -148500           -74250.00         -4.950000                     -2.48       (NKY) 11 JUN 2014 KEY ECB ANNOUNCEMENT_trade 59 days
# 30 2014-06-11 2014-06-12    2014-07-11        -0.06       34.32      -1.27        -9.93       -60000       59500               1             50             0         -25000           -25000.00         -0.833333                     -0.83       (NKY) 11 JUN 2014 KEY ECB ANNOUNCEMENT_trade 30 days
# 32 2017-06-05 2017-06-09    2017-07-14         0.02       52.48      -0.22        -9.07       -71000       59500               4             42             0        -483000          -120750.00        -16.100000                     -4.03  (NKY) 8 JUN 2017 EURZONE RATE ANNOUNCEMENT & U... 39 days
# 33 2017-06-05 2017-06-09    2017-08-10         0.01       68.22      -1.29        -7.06       -93500       85500               4             32             0        -256000           -64000.00         -8.533333                     -2.13  (NKY) 8 JUN 2017 EURZONE RATE ANNOUNCEMENT & U... 66 days
# 34 2017-06-06 2017-06-09    2017-07-14        -0.04       51.28      -1.47        -8.68       -66000       60000               3             45             0        -270000           -90000.00         -9.000000                     -3.00  (NKY) 8 JUN 2017 EURZONE RATE ANNOUNCEMENT & U... 38 days
# 16 2016-06-23 2016-06-24    2016-07-08         0.01       26.24      -0.30       -30.13       -90500      156500               1             33             0        2178000          2178000.00         72.600000                     72.60       (NKY) 23 JUN 2016 BREXIT ELECTION_trade 15 days
# 17 2016-06-23 2016-06-24    2016-08-12         0.02       47.82      -1.45       -13.37      -134000      176000               1             22             0         924000           924000.00         30.800000                     30.80       (NKY) 23 JUN 2016 BREXIT ELECTION_trade 50 days
# 20 2015-12-07 2015-12-10    2016-01-08        -0.04       46.39      -1.48       -12.61       -81000      102000               3             37             0         777000           259000.00         25.900000                      8.63   (NKY) 9 DEC 2015 KEY ECB ANNOUNCEMENT_trade 32 days
# 21 2015-12-07 2015-12-10    2016-02-12        -0.03       67.08      -3.28        -9.38      -126000      140000               3             24             0         336000           112000.00         11.200000                      3.73   (NKY) 9 DEC 2015 KEY ECB ANNOUNCEMENT_trade 67 days
# 22 2015-12-08 2015-12-10    2016-01-08         0.00       45.26      -0.82       -13.45       -83500       91000               2             36             0         270000           135000.00          9.000000                      4.50   (NKY) 9 DEC 2015 KEY ECB ANNOUNCEMENT_trade 31 days
# 23 2015-12-08 2015-12-10    2016-02-12         0.00       65.92      -2.37        -9.60      -127000      132000               2             24             0         120000            60000.00          4.000000                      2.00   (NKY) 9 DEC 2015 KEY ECB ANNOUNCEMENT_trade 66 days
# 24 2015-12-09 2015-12-10    2016-01-08         0.04       44.04      -0.06       -13.95       -84000       86000               1             36             0          72000            72000.00          2.400000                      2.40   (NKY) 9 DEC 2015 KEY ECB ANNOUNCEMENT_trade 30 days
# 25 2015-12-09 2015-12-10    2016-02-12        -0.01       64.73      -2.52        -9.86      -135000      136500               1             22             0          33000            33000.00          1.100000                      1.10   (NKY) 9 DEC 2015 KEY ECB ANNOUNCEMENT_trade 65 days
# 31 2014-06-11 2014-06-12    2014-08-08        -0.04       47.72      -2.43        -7.30       -85000       85500               1             35             0          17500            17500.00          0.583333                      0.58  (NKY) 11 JUN 2014 KEY ECB ANNOUNCEMENT_trade 58 days

# %%
mean_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].mean()
std_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].std()
count_above40 = df0[df0['dtm'].dt.days >= 40 ]['Average_Daily_Return_pct'].count()

print(mean_above40)
print(std_above40)
print(count_above40)
print("Sharpe ratio for dtm >= 40 days: ", mean_above40 / std_above40 / np.sqrt(count_above40))
# Out:
# 4.471363636363637
# 9.005542365124008
# 22
# Sharpe ratio for dtm >= 40 days:  0.10585680370024303

# %%
mean_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].mean()
std_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].std()
count_below40 = df0[df0['dtm'].dt.days < 40 ]['Average_Daily_Return_pct'].count()

print(mean_below40)
print(std_below40)
print(count_below40)
print("Sharpe ratio for dtm < 40 days: ", mean_below40 / std_below40 / np.sqrt(count_below40))
# Out:
# 7.159999999999997
# 19.047488251621317
# 24
# Sharpe ratio for dtm < 40 days:  0.07673079308691655
